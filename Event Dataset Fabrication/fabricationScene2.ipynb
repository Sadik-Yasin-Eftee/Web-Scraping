# %%
import pandas as pd

# %%
reviews_scene1= [
    "I launch the app before scrolling down the homepage until I tap on a news article.",
    "I open the app before tapping on the login button until it responds everytime it's pressed.",
    "When I launch the app then tap on the 'Videos' tab, the videos won't load as soon as I try to play any video.",
    "I open the app before tapping on the search bar then it crashes before I can type anything.",
    "I launch the app then swipe down to refresh the notifications until I tap on the bell icon.",
    "When I open the app, I scroll through the feed then it crashes when a notification pops up.",
    "After I launch the app, I tap on any image thumbnail until I close and reopen the app.",
    "I open the app then navigate to the settings page when I try to change any option.",
    "I open the app when I navigate to the chat section before the messages load properly.",
    "After I launch the app, I click on any external link after the first time I use the feature.",
    "I open the app when I make changes in the settings as soon as I hit the save button.",
    "When I open the app, I navigate between different sections everytime I switch tabs.",
    "I launch the app then scroll through any page until suddenly they vanish.",
    "After I open the app, I play any audio file until I force close the app.",
    "When I launch the app before attempting to comment on a post, the comment box doesn't appear.",
    "I open the app when I try to share a post then nothing happens when I tap on the share button."
]

outputs_scene1 = [
    {"App freezes": ["Launch the app", "Scroll down the homepage", "before the first tap on a news article"]},
    {"Login button not working": ["Open the app", "Tap on the login button", "until it responds everytime it's pressed"]},
    {"Videos won't load": ["Launch the app", "Tap on the 'Videos' tab", "as soon as I try to play any video"]},
    {"Search function crashes the app": ["Open the app", "Tap on the search bar", "before I can type anything"]},
    {"Notifications not showing up": ["Launch the app", "Swipe down to refresh the notifications", "then tap on the bell icon"]},
    {"App crashes": ["Open the app", "Scroll through the feed", "when a notification pops up"]},
    {"Images not loading": ["Launch the app", "Tap on any image thumbnail", "until I close and reopen the app"]},
    {"Buttons become unresponsive": ["Open the app", "Navigate to the settings page", "when I try to change any option"]},
    {"Text overlapping issue": ["Open the app", "Navigate to the chat section", "before the messages load properly"]},
    {"Links redirecting to wrong pages": ["Launch the app", "Click on any external link", "after the first time I use the feature"]},
    {"Settings not saving": ["Open the app", "Make changes in the settings", "as soon as I hit the save button"]},
    {"Slow loading times": ["Open the app", "Navigate between different sections", "everytime I switch tabs"]},
    {"UI elements disappearing randomly": ["Launch the app", "Scroll through any page", "then suddenly they vanish"]},
    {"Audio playback issues": ["Open the app", "Play any audio file", "until I force close the app"]},
    {"Unable to post comments": ["Launch the app", "Attempt to comment on a post", "before the comment box appears"]},
    {"Unable to share content": ["Open the app", "Try to share a post", "when I tap on the share button"]}
]

# %%
reviews_scene2 = [
    "I can only scroll down the homepage after I launch the app, but it freezes as soon as I tap on a news article.",
    "Everytime I open the app, the login button doesn't respond after I tap on it.",
    "The videos won't load as soon as I try to play any video after I launch the app and tap on the 'Videos' tab.",
    "Whenever I open the app and tap on the search bar, it crashes.",
    "Notifications are not showing up after I launch the app, swipe down to refresh the notifications, and tap on the bell icon.",
    "Everytime a notification pops up, the app crashes after I open the app and scroll through the feed.",
    "I can't upload photos as soon as I tap on the upload button after I take a picture with the app camera.",
    "Whenever I try to check my messages, the app logs me out.",
    "Everytime I try to make a purchase, the app crashes after I add items to the cart and proceed to checkout.",
    "I can't download updates as soon as I tap on the update button after the app notifies me of a new version.",
    "Whenever I try to edit my profile, the changes aren't saved.",
    "I can't see comments as soon as I open a post after I refresh my feed.",
    "Everytime I try to share a post, the app crashes after I write a caption.",
    "Whenever I try to change my password, the app logs me out.",
    "I can't read articles as soon as I click on them after I launch the app.",
    "Everytime I open the settings menu, the app freezes after I scroll down.",
    "Whenever I try to watch live streams, the video buffers indefinitely."
]

outputs_scene2 = [
    {"App freezes when tapping on a news article": ["Scroll down the homepage", "Launch the app"]},
    {"Login button doesn't respond": ["Open the app", "Tap on the login button"]},
    {"Videos won't load": ["Play any video", "Launch the app", "Tap on the 'Videos' tab"]},
    {"App crashes when tapping on the search bar": ["Open the app", "Tap on the search bar"]},
    {"Notifications are not showing up": ["Launch the app", "Swipe down to refresh the notifications", "Tap on the bell icon"]},
    {"App crashes when a notification pops up": ["Open the app", "Scroll through the feed"]},
    {"Cannot upload photos": ["Tap on the upload button", "Take a picture with the app camera"]},
    {"App logs out when checking messages": ["Try to check messages"]},
    {"App crashes when making a purchase": ["Add items to the cart", "Proceed to checkout"]},
    {"Cannot download updates": ["Tap on the update button", "App notifies of a new version"]},
    {"Profile changes aren't saved": ["Try to edit profile"]},
    {"Cannot see comments": ["Open a post", "Refresh feed"]},
    {"App crashes when sharing a post": ["Write a caption"]},
    {"App logs out when changing password": ["Try to change password"]},
    {"Cannot read articles": ["Click on articles", "Launch the app"]},
    {"App freezes in settings menu": ["Open the settings menu", "Scroll down"]},
    {"Video buffers indefinitely": ["Try to watch live streams"]}
]

# %%
reviews_scene3 = [
    "When trying to post a status, the app crashes constantly after typing the status and clicking on 'Post'.",
    "While scrolling through the feed, notifications fail to appear every time I scroll.",
    "As soon as I click on a video to watch, videos randomly freeze during playback.",
    "When attempting to send a message, messages fail to send after composing the message and hitting send.",
    "When uploading a photo, photos do not upload properly after selecting the photo and clicking on the 'Upload' button.",
    "When accessing settings, changes to settings are not saved every time I attempt to modify a setting.",
    "After typing the post and clicking on the 'Publish' button, posts disappear after composing a post.",
    "When commenting on a post, comments do not show up after typing the comment and clicking on the 'Submit' button.",
    "When updating profile information, profile information does not update after making changes and clicking on the 'Save' button.",
    "After selecting the reaction and clicking on the 'React' button, reactions are not registered after reacting to a post.",
    "Every time I try to view a story, stories fail to load when attempting to view stories.",
    "Every time I click on the 'Like' button, likes do not appear after liking a post.",
    "When trying to share a post, shares are not successful after selecting 'Share' and choosing the platform.",
    "When accessing events, events are not displayed every time I try to view upcoming events.",
    "When attempting to join a group, groups are inaccessible after clicking on the 'Join Group' button.",
    "Every time I attempt to access a page, pages do not load properly when accessing pages.",
    "After entering keywords and hitting the 'Search' button, search results are not relevant when performing a search."
]

outputs_scene3 = [
    [{"App constantly crashing": ["Trying to post a status", "After typing the status and clicking on 'Post'"]}],
    [{"Notifications not showing up": ["Scrolling through the feed", "Every time I scroll through the feed"]}],
    [{"Videos freezing randomly": ["Watching videos", "As soon as I click on a video to watch"]}],
    [{"Messages not sending": ["Trying to send a message", "After composing the message and hitting send"]}],
    [{"Photos not uploading properly": ["Uploading a photo", "After selecting the photo and clicking on 'Upload'"]}],
    [{"Settings not saving changes": ["Accessing settings", "Every time I attempt to modify a setting"]}],
    [{"Posts disappearing": ["Writing a post", "After typing the post and clicking on 'Publish'"]}],
    [{"Comments not appearing": ["Commenting on a post", "After typing the comment and clicking on the 'Submit'"]}],
    [{"Profile information not updating": ["Updating profile information", "After making changes and clicking on the 'Save'"]}],
    [{"Reactions not registering": ["Reacting to a post", "After selecting the reaction and clicking on the 'React'"]}],
    [{"Stories not loading": ["Viewing stories", "Every time I try to view a story"]}],
    [{"Likes not showing up": ["Liking a post", "Every time I click on the 'Like' button"]}],
    [{"Shares not going through": ["Trying to share a post", "After selecting 'Share' and choosing the platform"]}],
    [{"Events not displaying": ["Accessing events", "Every time I try to view upcoming events"]}],
    [{"Groups not accessible": ["Joining a group", "After clicking on the 'Join Group' button"]}],
    [{"Pages not loading properly": ["Accessing pages", "Every time I attempt to access a page"]}],
    [{"Search results not relevant": ["Searching", "After entering keywords and hitting the 'Search' button"]}]
]

# %%
scenario2 = pd.DataFrame({
    "Reviews": reviews_scene1 + reviews_scene2 + reviews_scene3, 
    "Outputs": list(outputs_scene1) + list(outputs_scene2) + list(outputs_scene3)
})

scenario2.head()
# Out:
#                                              Reviews  \
# 0  I launch the app before scrolling down the hom...
# 1  I open the app before tapping on the login but...
# 2  When I launch the app then tap on the 'Videos'...
# 3  I open the app before tapping on the search ba...
# 4  I launch the app then swipe down to refresh th...
#
#                                              Outputs
# 0  {'App freezes': ['Launch the app', 'Scroll dow...
# 1  {'Login button not working': ['Open the app', ...
# 2  {'Videos won't load': ['Launch the app', 'Tap ...
# 3  {'Search function crashes the app': ['Open the...
# 4  {'Notifications not showing up': ['Launch the ...

# %%
scenario2.to_csv("scenario2.csv", index=False)

# %%
app_reviews = [
    "The app crashes unexpectedly every time I try to open it or navigate to settings. Can't even get started properly!",
    "I enabled notifications but they're not showing up, even after refreshing the app multiple times. Very frustrating!",
    "Buttons in the app are unresponsive, even after tapping on them and restarting the app. Needs fixing!",
    "Images fail to load in the feed, despite refreshing it and ensuring a stable internet connection.",
    "The search function isn't working properly; it's not showing accurate results even after typing in the search query and selecting a result.",
    "Battery drains quickly, especially when using the app to watch videos. Needs optimization!",
    "Sound cuts out randomly while watching videos, making it impossible to enjoy any audio content.",
    "The settings menu closes abruptly, preventing me from adjusting any preferences. Very annoying!",
    "Fonts in the app appear distorted, affecting the readability of text across different screens.",
    "The app switches to random screens unexpectedly, causing confusion and disruption in usage.",
    "Data doesn't sync between devices, despite attempting to sync data and checking sync settings.",
    "The camera feature is inaccessible, even after trying to use it and granting necessary permissions.",
    "The app crashes repeatedly, making it extremely frustrating to use on a daily basis.",
    "GPS freezes intermittently, making it difficult to get accurate directions while using the navigation feature.",
    "Videos won't play, even after clicking on them and waiting for them to load.",
    "Buttons in the app don't respond at all, even after tapping on them multiple times and force closing and reopening the app.",
    "The app freezes when playing videos, especially when navigating away from the video.",
    "Notifications disappear after receiving them, causing me to miss important updates.",
    "Search results aren't accurate, even after typing in the search query and viewing the search results.",
    "Battery drains rapidly, even when the app is idle and not in use.",
    "Sound quality deteriorates while listening to audio, despite changing audio settings.",
    "The settings menu crashes frequently, hindering the ability to adjust preferences effectively.",
    "Fonts in the app change size unexpectedly, affecting the overall user experience.",
    "The app freezes during navigation, making it difficult to use different features.",
    "The camera doesn't focus properly, despite using the camera feature and adjusting camera settings.",
    "The app crashes on startup, making it impossible to access any features or functionalities.",
    "GPS provides inaccurate directions, leading to confusion while using the navigation feature.",
    "Videos buffer indefinitely, even after checking the internet connection.",
    "Buttons register double taps, causing unintended actions in the app.",
    "The app crashes when opening a specific file, making it impossible to access the file.",
    "Notifications are delayed, even after receiving them and restarting the device.",
    "The search function causes the app to freeze, especially after typing in the search query.",
    "Battery drains rapidly during calls, even after making adjustments to battery usage.",
    "Sound echoes during calls, making it difficult to communicate effectively.",
    "The settings menu doesn't save changes, even after changing settings multiple times.",
    "Fonts in the app become blurry, affecting readability and overall user experience.",
    "The app freezes during video calls, making it impossible to communicate effectively.",
    "GPS is unable to find the current location, even after checking location settings.",
    "Videos stutter during playback, even after restarting the app.",
    "Buttons in the app trigger unintended actions, causing frustration during usage.",
    "The app crashes when accessing a specific feature, hindering overall usability.",
    "Notifications show outdated information, even after checking app settings.",
    "The search function returns no results, even after typing in the search query.",
    "Battery drains even in power-saving mode, despite minimizing background apps.",
    "Sound distorts at high volume, affecting the overall audio experience.",
    "The settings menu layout glitches frequently, causing frustration during navigation.",
    "Fonts in the app appear too small to read, even after adjusting font size settings.",
    "The app freezes when switching between tabs, hindering smooth navigation.",
    "The camera app crashes when switching modes, making it impossible to use different camera features.",
    "GPS loses signal intermittently, leading to disruptions while using the navigation feature."
]

# %%
app_outputs = [
    {"App crashes unexpectedly": ["Opening the app", "Navigating to settings"]},
    {"Notifications not showing up": ["Enabling notifications", "Refreshing the app"]},
    {"Buttons unresponsive": ["Tapping on buttons", "Restarting the app"]},
    {"Images fail to load": ["Refreshing the feed", "Checking internet connection"]},
    {"Search function not working": ["Typing in search query", "Selecting search result"]},
    {"Battery drains quickly": ["Using the app", "Playing videos"]},
    {"Sound cuts out randomly": ["Watching videos", "Adjusting volume"]},
    {"Settings menu closes abruptly": ["Accessing settings", "Trying to change preferences"]},
    {"Fonts appear distorted": ["Opening the app", "Navigating to different screens"]},
    {"App switches to random screens": ["Using different features", "Closing and reopening the app"]},
    {"Data not syncing between devices": ["Attempting to sync data", "Checking sync settings"]},
    {"Camera feature inaccessible": ["Trying to use camera", "Granting camera permissions"]},
    {"App crashes repeatedly": ["Opening the app", "Navigating to specific feature"]},
    {"GPS freezes intermittently": ["Using GPS feature", "Restarting the app"]},
    {"Videos won't play": ["Clicking on video", "Waiting for video to load"]},
    {"No response from buttons": ["Tapping on buttons", "Force closing and reopening app"]},
    {"App freezes when playing videos": ["Playing videos", "Navigating away from video"]},
    {"Notifications disappearing": ["Receiving notification", "Opening the app"]},
    {"Search results not accurate": ["Typing in search query", "Viewing search results"]},
    {"Battery draining while idle": ["Closing the app", "Checking battery usage"]},
    {"Sound quality deteriorates": ["Listening to audio", "Changing audio settings"]},
    {"Settings menu crashing": ["Accessing settings", "Navigating between settings options"]},
    {"Fonts changing size unexpectedly": ["Opening the app", "Changing device orientation"]},
    {"App freezing during navigation": ["Navigating through app pages", "Force closing and reopening app"]},
    {"Camera not focusing properly": ["Using camera feature", "Adjusting camera settings"]},
    {"App crashing on startup": ["Launching the app", "Checking for app updates"]},
    {"GPS providing inaccurate directions": ["Using GPS feature", "Switching to different navigation app"]},
    {"Videos buffering indefinitely": ["Watching videos", "Checking internet connection"]},
    {"Buttons triggering unintended actions": ["Tapping on buttons", "Adjusting touch sensitivity"]},
    {"App crashing when opening specific file": ["Opening file", "Checking file format"]},
    {"Notifications delayed": ["Receiving notification", "Restarting device"]},
    {"Search function causing app to freeze": ["Typing in search query", "Closing keyboard"]},
    {"Battery draining rapidly during calls": ["Making phone call", "Checking battery usage"]},
    {"Sound echoing during calls": ["Making phone call", "Adjusting call settings"]},
    {"Settings menu not saving changes": ["Changing settings", "Closing and reopening app"]},
    {"Fonts becoming blurry": ["Using different app features", "Restarting device"]},
    {"App freezing during video calls": ["Making video call", "Restarting app"]},
    {"GPS unable to find current location": ["Using GPS feature", "Checking location settings"]},
    {"Videos stuttering during playback": ["Watching videos", "Restarting app"]},
    {"Buttons registering double taps": ["Tapping on buttons", "Restarting the app"]},
    {"App crashing when accessing specific feature": ["Using specific feature", "Updating app"]},
    {"Notifications showing outdated information": ["Receiving notification", "Checking app settings"]},
    {"Search function returning no results": ["Typing in search query", "Clearing search history"]},
    {"Battery draining even in power saving mode": ["Enabling power saving mode", "Checking background apps"]},
    {"Sound distorting at high volume": ["Adjusting volume", "Restarting device"]},
    {"Settings menu layout glitching": ["Accessing settings", "Switching between settings options"]},
    {"Fonts appearing too small to read": ["Opening the app", "Adjusting font size settings"]},
    {"App freezing when switching between tabs": ["Navigating between app tabs", "Restarting app"]},
    {"Camera app crashing when switching modes": ["Switching camera modes", "Restarting phone"]},
    {"GPS losing signal intermittently": ["Using GPS feature", "Restarting app"]}
]

# %%
scenario2_1 = pd.DataFrame({
    "Reviews": app_reviews,
    "Outputs": app_outputs
})

scenario2_1.head()
# Out:
#                                              Reviews  \
# 0  The app crashes unexpectedly every time I try ...
# 1  I enabled notifications but they're not showin...
# 2  Buttons in the app are unresponsive, even afte...
# 3  Images fail to load in the feed, despite refre...
# 4  The search function isn't working properly; it...
#
#                                              Outputs
# 0  {'App crashes unexpectedly': ['Opening the app...
# 1  {'Notifications not showing up': ['Enabling no...
# 2  {'Buttons unresponsive': ['Tapping on buttons'...
# 3  {'Images fail to load': ['Refreshing the feed'...
# 4  {'Search function not working': ['Typing in se...

# %%
scenario2_1.to_csv("scenario2_1.csv", index=False)

# %%
reviews1 = [
    "This app is infuriating. I tried to transfer money to my friend, but the process was a nightmare. First, the app crashed multiple times while trying to access my contacts. When it finally worked, the app couldn't recognize my friend's username despite it being correct. After several attempts, the transfer finally went through, but then I noticed that the app had deducted the amount twice from my account! I contacted customer service, but they were unresponsive. Avoid this app at all costs.",
    "Terrible experience trying to pay my utility bill using this app. The app froze while entering my payment details and then crashed completely. After restarting, I had to re-enter all my information, only to get an error message saying the payment could not be processed. I checked my bank account and saw that the amount had been deducted anyway. Now I'm stuck with a pending payment and no way to resolve it because customer support is unreachable. Absolutely unacceptable.",
    "I tried booking a flight and hotel package, and it was a complete disaster. The app kept timing out during the search process, and when it finally found options, it wouldn't let me select the flight I wanted. After several retries, I managed to get to the payment screen, but the app wouldn't accept my credit card information, saying it was invalid. I used the same card on another site without any issues. To top it off, when I checked my email, I had multiple confirmations for the same booking, all charged to my card. Now I'm dealing with the hassle of cancellations and refunds. Frustrating beyond belief.",
    "Trying to book a rental car was a nightmare. The app was painfully slow, and every time I selected a car, it would say 'car not available' after going through all the details. When I finally found one that seemed available, the app crashed at the payment stage. After restarting, it showed the car as booked, but I never received a confirmation email. Customer service is useless – they claim there's no record of my booking even though my card was charged. This app is unreliable and a huge waste of time.",
    "I tried to log my workout, and it was a frustrating experience. The app took forever to load and then crashed as soon as I tried to enter my exercise details. When I finally got it to stay open, it wouldn't save my workout and kept giving me a 'network error' despite having a strong Wi-Fi connection. After several attempts, it eventually saved my workout twice, but with incorrect data. The syncing with my smartwatch is also hit-or-miss. Extremely disappointing.",
    "Logging meals on this app is a joke. The barcode scanner rarely works, and when it does, the nutritional information is often wrong. Manually entering meals is no better – the app frequently crashes or freezes, and the database of foods is incomplete. On top of that, the app failed to sync with my fitness tracker, so my calorie count is always off. Customer support has been no help, just generic responses that don't address the issues. This app is more hassle than it's worth.",
    "Terrible app. I tried to purchase a few items, but the experience was horrendous. The app kept removing items from my cart randomly. When I tried to proceed to checkout, it gave me an error message saying some items were out of stock, even though they were still listed as available. After finally managing to place the order, the payment screen glitched and charged my card twice. Now I'm dealing with double charges and missing items from my order. Customer service is not responding to my emails. Never using this app again.",
    "Horrible user experience trying to order a gift. The app was incredibly slow, and every time I added something to my cart, it took forever to update. When I went to checkout, the app crashed repeatedly. After finally getting through, my payment was declined for no apparent reason, even though my card is fine. When I tried a different card, it went through, but the order status shows pending for days now. No updates, no tracking info, and customer support is non-existent. Extremely frustrating.",
    "Terrible service. The internet is constantly dropping, and when it does work, it's painfully slow. Customer service is useless – long wait times and no resolution to the issues. I've been overcharged multiple times, and getting a refund is a nightmare. Switching to a different provider ASAP.",
    "Very disappointed with FastNet. The connection is unreliable, and the speeds are nowhere near what was advertised. The installation process was a hassle, and the technician was late. Customer support is unresponsive and unhelpful. Not recommended."
]

outputs1 = [
    [
        {"app crashes": ["transfer money to a friend"]},
        {"can't recognize username": ["transfer money to a friend"]},
        {"deducted amount twice": ["transfer money to a friend"]}
    ],
    [
        {"app freezes": ["enter payment details for utility bill"]},
        {"app crashes": ["enter payment details for utility bill"]},
        {"payment deducted but not processed": ["enter payment details for utility bill"]}
    ],
    [
        {"app times out": ["search for flight and hotel package"]},
        {"won't accept credit card information": ["enter payment information for flight and hotel package"]},
        {"multiple confirmations and charges": ["book flight and hotel package"]}
    ],
    [
        {"app is slow": ["select rental car"]},
        {"car not available error": ["select rental car"]},
        {"app crashes": ["make payment for rental car"]},
        {"no confirmation email": ["book rental car"]}
    ],
    [
        {"app takes forever to load": ["log workout"]},
        {"app crashes": ["log workout"]},
        {"network error": ["save workout"]},
        {"incorrect data saved": ["save workout"]}
    ],
    [
        {"barcode scanner rarely works": ["log meals"]},
        {"nutritional information is wrong": ["log meals"]},
        {"app crashes or freezes": ["manually enter meals"]},
        {"database of foods is incomplete": ["log meals"]},
        {"failed to sync with fitness tracker": ["log meals"]}
    ],
    [
        {"app removes items from cart": ["add items to cart"]},
        {"error message saying items out of stock": ["proceed to checkout"]},
        {"payment screen glitches and charges card twice": ["make payment"]},
        {"missing items from order": ["place order"]}
    ],
    [
        {"app is slow": ["add items to cart"]},
        {"app crashes": ["checkout"]},
        {"payment declined for no reason": ["make payment"]},
        {"order status shows pending for days": ["place order"]}
    ],
    [
        {"internet constantly drops": ["use internet"]},
        {"internet is painfully slow": ["use internet"]},
        {"long wait times for customer service": ["contact customer service"]},
        {"no resolution to issues": ["contact customer service"]}
    ],
    [
        {"connection is unreliable": ["use internet"]},
        {"speeds not as advertised": ["use internet"]},
        {"installation process is a hassle": ["get internet installed"]},
        {"technician is late": ["get internet installed"]},
        {"customer support is unresponsive": ["contact customer support"]}
    ]
]

# %%
reviews2 = [
    "I tried to sign up for a new account and the app was a mess. It kept saying my email was invalid even though it was correct. When I finally got past that, the verification code never arrived in my inbox. After requesting it multiple times, I received several codes at once, none of which worked. Customer service didn't help at all. Frustrating experience.",
    "Booking a concert ticket through this app was a disaster. First, the app crashed multiple times while searching for events. When it finally loaded, the seat selection was glitchy and wouldn't let me choose my preferred seats. After several tries, I managed to book a ticket, but then the app double-charged my card. Now I have two charges and only one ticket. Unacceptable.",
    "I attempted to update my profile picture, but the app was incredibly buggy. It took forever to load the photo gallery, and when I finally selected a picture, it either failed to upload or uploaded a distorted version. I tried several times with the same result. Also, it logged me out unexpectedly during the process. Terrible user experience.",
    "Trying to check my account balance was a nightmare. The app was extremely slow to open, and when it finally did, it showed incorrect balance information. I refreshed multiple times but got the same wrong balance. To make matters worse, the app crashed several times while I was trying to navigate through the menus. Unreliable and frustrating.",
    "I tried to book a table at a restaurant, and the app failed miserably. It kept showing 'no availability' for times that were clearly open on the restaurant's website. When I finally got a reservation, the app crashed and didn't save it. I had to start over, and it happened again. I ended up calling the restaurant directly. A total waste of time.",
    "Downloading a PDF document using this app was impossible. The download button was unresponsive, and when it finally worked, the app crashed halfway through the download. After restarting, the document wouldn't open, saying it was corrupted. Tried multiple times with the same result. Very disappointing.",
    "I tried to update the app to the latest version, but it was a disaster. The update process froze multiple times and eventually corrupted the app, making it unusable. I had to uninstall and reinstall it, losing all my saved data in the process. The new version also has more bugs than the old one. Completely unacceptable.",
    "Attempting to log my sleep data with this app was a nightmare. The app was slow to open and kept crashing when I tried to enter my sleep hours. When it finally worked, the data wasn't saved correctly and showed inaccurate sleep times. Syncing with my smartwatch was also problematic. Not worth the hassle.",
    "I tried to pay for parking using this app, and it was an infuriating experience. The app took forever to load my location and then wouldn't accept my payment method, saying it was invalid. After multiple attempts, it finally went through, but the parking session wasn't activated, and I received a fine. Customer support was no help at all. Never using this app again.",
    "I attempted to use the app to track my package delivery, but it was useless. The app was extremely slow to load the tracking information, and when it did, it was outdated and incorrect. The app crashed several times while I was trying to refresh the tracking info. I ended up having to call customer service to get accurate information. Very frustrating."
]

outputs2 = [
    [
        {"email invalid": ["sign up for a new account"]},
        {"verification code never arrived": ["sign up for a new account"]},
        {"multiple codes received, none worked": ["sign up for a new account"]},
        {"customer service didn't help": ["sign up for a new account"]}
    ],
    [
        {"app crashed": ["search for events"]},
        {"glitchy seat selection": ["choose preferred seats"]},
        {"double-charged card": ["book a concert ticket"]}
    ],
    [
        {"app buggy": ["update profile picture"]},
        {"photo gallery slow to load": ["update profile picture"]},
        {"failed to upload": ["update profile picture"]},
        {"uploaded distorted version": ["update profile picture"]},
        {"logged out unexpectedly": ["update profile picture"]}
    ],
    [
        {"app slow to open": ["check account balance"]},
        {"incorrect balance information": ["check account balance"]},
        {"app crashed": ["navigate through menus"]}
    ],
    [
        {"no availability shown": ["book a table at a restaurant"]},
        {"app crashed": ["save reservation"]},
        {"had to call restaurant directly": ["book a table at a restaurant"]}
    ],
    [
        {"download button unresponsive": ["download a PDF document"]},
        {"app crashed during download": ["download a PDF document"]},
        {"document corrupted": ["download a PDF document"]}
    ],
    [
        {"update process froze": ["update the app"]},
        {"app corrupted": ["update the app"]},
        {"lost saved data": ["reinstall the app"]},
        {"new version has more bugs": ["use the updated app"]}
    ],
    [
        {"app slow to open": ["log sleep data"]},
        {"app crashed": ["enter sleep hours"]},
        {"data not saved correctly": ["log sleep data"]},
        {"inaccurate sleep times": ["log sleep data"]},
        {"syncing with smartwatch problematic": ["log sleep data"]}
    ],
    [
        {"app took forever to load location": ["pay for parking"]},
        {"payment method invalid": ["pay for parking"]},
        {"parking session not activated": ["pay for parking"]},
        {"received a fine": ["pay for parking"]},
        {"customer support no help": ["pay for parking"]}
    ],
    [
        {"app slow to load tracking information": ["track package delivery"]},
        {"outdated and incorrect tracking information": ["track package delivery"]},
        {"app crashed": ["refresh tracking info"]},
        {"had to call customer service": ["track package delivery"]}
    ]
]

# %%
reviews3 = [
    "Attempting to reset my password was a nightmare. The app constantly gave me an 'error' message when I tried to submit my new password. When it finally accepted a password, the confirmation email never arrived. I tried logging in with the new password, but it didn't work. Customer support was useless and kept telling me to try the same steps over and over.",
    "Downloading music using this app was incredibly frustrating. The app was slow to load my library and frequently crashed when I tried to add songs to my playlist. When I finally managed to download a few songs, they wouldn't play offline. I had to redownload them multiple times, and they still wouldn't work properly. Terrible experience.",
    "I tried to use the app to order groceries, and it was a complete mess. The app was slow and unresponsive while browsing items. Several items in my cart were suddenly marked as unavailable at checkout, even though they were listed as in stock. After finally placing the order, the delivery status kept showing errors, and I never received my groceries. Horrible service.",
    "Signing up for a gym membership through this app was a disaster. The app crashed multiple times during the signup process and lost all my information. When I finally got through, the payment screen glitched and double-charged me. Customer support has been unresponsive, and I'm now stuck with two charges for one membership.",
    "Trying to book a doctor's appointment was infuriating. The app kept giving me errors when I selected available times. When I finally got an appointment confirmed, the app crashed and lost the booking. I had to start over, and the same thing happened again. Eventually, I had to call the clinic directly. Very frustrating.",
    "I tried to use the app to check in for my flight, and it was a terrible experience. The app was extremely slow to load my booking details, and when it finally did, it wouldn't let me select my seat. After multiple attempts, I got an error message saying check-in was unavailable. I ended up having to check in at the airport. A waste of time.",
    "Managing my subscriptions with this app is a nightmare. The app often freezes when I try to update my payment information. When it finally goes through, it sometimes processes the update incorrectly, leading to failed payments. Additionally, it doesn't notify me of upcoming renewals, causing unexpected charges. Completely unreliable.",
    "I tried to use this app to monitor my home's security cameras, but it's terrible. The app crashes frequently, and the live feed is often delayed or fails to load. Motion alerts are unreliable, sometimes not triggering at all. Overall, it fails at its primary function and makes me feel less secure.",
    "I tried to use the app to schedule a maintenance appointment for my car, and it was awful. The app was slow to load available dates, and when I selected a time, it gave me an error message. After multiple tries, I got a confirmation, but the appointment never appeared in the app. I had to call the service center directly. Very inefficient.",
    "Attempting to join a virtual class using this app was a frustrating experience. The app frequently disconnected from the internet, and when it stayed connected, the video quality was poor and laggy. Additionally, the audio would cut out randomly, making it hard to follow along. I missed most of the class due to these issues. Very disappointing."
]

outputs3 = [
    [
        {"error message": ["reset my password"]},
        {"confirmation email never arrived": ["reset my password"]},
        {"new password didn't work": ["reset my password"]},
        {"customer support was useless": ["reset my password"]}
    ],
    [
        {"app slow to load library": ["download music"]},
        {"app crashed": ["add songs to playlist"]},
        {"songs wouldn't play offline": ["download music"]},
        {"had to redownload multiple times": ["download music"]}
    ],
    [
        {"app slow and unresponsive": ["order groceries"]},
        {"items marked as unavailable at checkout": ["order groceries"]},
        {"delivery status showing errors": ["place order"]},
        {"never received groceries": ["order groceries"]}
    ],
    [
        {"app crashed": ["sign up for a gym membership"]},
        {"lost all information": ["sign up for a gym membership"]},
        {"payment screen glitched": ["sign up for a gym membership"]},
        {"double-charged": ["sign up for a gym membership"]},
        {"customer support unresponsive": ["sign up for a gym membership"]}
    ],
    [
        {"errors when selecting available times": ["book a doctor's appointment"]},
        {"app crashed and lost booking": ["book a doctor's appointment"]},
        {"had to call the clinic directly": ["book a doctor's appointment"]}
    ],
    [
        {"app slow to load booking details": ["check in for my flight"]},
        {"wouldn't let me select my seat": ["check in for my flight"]},
        {"error message": ["check in for my flight"]},
        {"had to check in at the airport": ["check in for my flight"]}
    ],
    [
        {"app freezes": ["update payment information"]},
        {"processed update incorrectly": ["update payment information"]},
        {"failed payments": ["update payment information"]},
        {"no notifications for renewals": ["manage subscriptions"]},
        {"unexpected charges": ["manage subscriptions"]}
    ],
    [
        {"app crashes frequently": ["monitor security cameras"]},
        {"live feed delayed or fails to load": ["monitor security cameras"]},
        {"motion alerts unreliable": ["monitor security cameras"]},
        {"fails at primary function": ["monitor security cameras"]}
    ],
    [
        {"app slow to load dates": ["schedule a maintenance appointment"]},
        {"error message": ["schedule a maintenance appointment"]},
        {"appointment never appeared in app": ["schedule a maintenance appointment"]},
        {"had to call service center directly": ["schedule a maintenance appointment"]}
    ],
    [
        {"app frequently disconnected": ["join a virtual class"]},
        {"poor video quality": ["join a virtual class"]},
        {"audio cut out randomly": ["join a virtual class"]},
        {"missed most of the class": ["join a virtual class"]}
    ]
]

# %%
reviews4 = [
    "Using this app to order food was a complete disaster. The app was slow to load the menu items, and when I finally selected my order, it crashed during checkout. After reopening the app, my cart was empty, and I had to start over. Once I managed to place the order, the delivery was late, and some items were missing. Customer service was unresponsive, and I never got a refund for the missing items.",
    "I tried to use this app to apply for a loan, and it was a frustrating experience. The app kept giving me errors during the application process, and when I finally completed it, there was no confirmation. I tried checking my application status, but the app crashed every time I tried to access it. I never got any updates on my loan status, and customer support couldn't help either.",
    "Using this app to track my expenses was a nightmare. The app frequently froze when I tried to input transactions, and sometimes it would duplicate entries without warning. When I tried to generate a monthly report, the app crashed, and I lost all my progress. I had to manually input everything again, defeating the purpose of using the app in the first place.",
    "I attempted to use this app to find a job, but it was a waste of time. The app was slow to load job listings, and when I applied to a few, I never got any confirmation emails. I tried checking my application status, but the app crashed every time I tried to access it. After weeks of waiting, I never heard back from any of the companies. Very disappointing.",
    "I tried to use this app to book a vacation package, but it was a complete disaster. The app was slow and unresponsive, and when I finally selected a package, it crashed during checkout. After restarting the app, I found that my booking was lost, and I had to start over. When I finally managed to complete the booking, I received multiple confirmations for the same trip, each with different details. It took weeks to resolve the issue with customer support.",
    "Using this app to pay my bills was a frustrating experience. The app frequently crashed when I tried to add new payees, and sometimes it would log me out randomly. When I finally managed to add a payee and make a payment, the app didn't update my account balance correctly. I had to call customer support to confirm the payment went through, and they were unable to provide any assistance.",
    "I attempted to use this app to file my taxes, but it was a complete disaster. The app was slow and glitchy, and it frequently crashed during the data entry process. When I finally managed to input all my information, the app gave me an error message saying my return couldn't be processed. I tried contacting customer support, but they were unresponsive. I ended up filing my taxes manually.",
    "Using this app to order clothes online was a terrible experience. The app was slow to load product images, and sometimes it would show items as available when they were out of stock. When I finally managed to place an order, the app crashed during checkout, and I had to restart the process. After completing the order, I never received a confirmation email, and my order never arrived. Customer support was useless.",
    "I tried to use this app to track my investments, but it was a nightmare. The app frequently crashed when I tried to view my portfolio, and sometimes it would show incorrect balances. When I tried to execute a trade, the app would freeze, and I had to restart it. After several failed attempts, I gave up and switched to a different investment tracking app.",
    "Using this app to book a restaurant reservation was a frustrating experience. The app was slow to load available times, and sometimes it would show times as available when they were fully booked. When I finally managed to make a reservation, the app crashed, and my booking was lost. I had to call the restaurant directly to confirm my reservation, and they had no record of it."
]


outputs4 = [
    [
        {"app slow to load menu items": ["order food"]},
        {"app crashed during checkout": ["order food"]},
        {"cart emptied after app restart": ["order food"]},
        {"delivery late, items missing": ["order food"]},
        {"customer service unresponsive": ["order food"]}
    ],
    [
        {"app gave errors during application process": ["apply for a loan"]},
        {"no confirmation after completing application": ["apply for a loan"]},
        {"app crashed when checking application status": ["apply for a loan"]},
        {"no updates on loan status": ["apply for a loan"]},
        {"customer support couldn't help": ["apply for a loan"]}
    ],
    [
        {"app froze when inputting transactions": ["track expenses"]},
        {"duplicated entries without warning": ["track expenses"]},
        {"app crashed when generating report": ["track expenses"]},
        {"lost progress after app crash": ["track expenses"]}
    ],
    [
        {"app slow to load job listings": ["find a job"]},
        {"no confirmation emails after applying": ["find a job"]},
        {"app crashed when checking application status": ["find a job"]},
        {"no response from companies": ["find a job"]}
    ],
    [
        {"app slow and unresponsive": ["book a vacation package"]},
        {"app crashed during checkout": ["book a vacation package"]},
        {"booking lost after app restart": ["book a vacation package"]},
        {"multiple confirmations for same trip": ["book a vacation package"]},
        {"weeks to resolve issue with customer support": ["book a vacation package"]}
    ],
    [
        {"app crashed when adding new payees": ["pay bills"]},
        {"app logged out randomly": ["pay bills"]},
        {"app didn't update account balance correctly": ["pay bills"]},
        {"customer support unable to assist": ["pay bills"]}
    ],
    [
        {"app slow and glitchy": ["file taxes"]},
        {"app crashed during data entry": ["file taxes"]},
        {"return couldn't be processed": ["file taxes"]},
        {"customer support unresponsive": ["file taxes"]}
    ],
    [
        {"app slow to load product images": ["order clothes online"]},
        {"items shown as available when out of stock": ["order clothes online"]},
        {"app crashed during checkout": ["order clothes online"]},
        {"no confirmation email, order never arrived": ["order clothes online"]},
        {"customer support useless": ["order clothes online"]}
    ],
    [
        {"app crashed when viewing portfolio": ["track investments"]},
        {"incorrect balances shown": ["track investments"]},
        {"app froze when executing trade": ["track investments"]},
        {"switched to different investment tracking app": ["track investments"]}
    ],
    [
        {"app slow to load available times": ["book a restaurant reservation"]},
        {"times shown as available when fully booked": ["book a restaurant reservation"]},
        {"app crashed, booking lost": ["book a restaurant reservation"]},
        {"restaurant had no record of reservation": ["book a restaurant reservation"]}
    ]
]

# %%
reviews5 = [
    "Trying to use this app to schedule a home repair was a nightmare. It was slow to load available appointment slots, and when I finally found one, the app crashed during confirmation. After restarting, my booking was lost, and I had to repeat the process. To make matters worse, customer support was unresponsive when I tried to get assistance.",
    "I attempted to use this app to order a birthday cake, but it was a disaster. The app was sluggish when browsing cake designs, and it frequently froze during checkout. After finally completing the order, the app crashed, and my payment was not processed. Despite multiple attempts to contact customer service, I received no response.",
    "Using this app to find a tutor for my child was a frustrating experience. It was slow to load available tutors, and sometimes it would show tutors as available when they were fully booked. When I finally managed to book a session, the app crashed, and my booking was lost. I had to call the tutoring center directly to schedule a session.",
    "I tried to use this app to track my medication, but it was a total letdown. It frequently crashed when I tried to input my doses, and sometimes it would delete entries without warning. When I tried to set reminders for my medication, the app froze, and the reminders were not set. I ended up missing doses because of the app's unreliability.",
    "Using this app to find a dog walker was a nightmare. It was slow to load available walkers, and sometimes it would show walkers as available when they were not. When I finally managed to book a walk, the app crashed, and my booking was lost. I had to find a walker through other means due to the app's incompetence.",
    "I attempted to use this app to order a meal delivery, but it was a complete mess. It was slow to load available restaurants, and sometimes it would show places as open when they were closed. After finally placing an order, the app crashed during checkout, and my order was lost. Customer support was unable to assist in resolving the issue.",
    "Trying to use this app to book a rental car was a nightmare. It was slow to load available vehicles, and sometimes it would show cars as available when they were not. When I finally managed to book a car, the app crashed, and my booking was lost. I had to call the rental company directly to secure a reservation.",
    "I tried to use this app to order groceries, but it was a total disaster. It was slow to load available items, and sometimes it would show products as available when they were out of stock. After finally completing my order, the app crashed, and my cart was emptied. I had to start over, wasting valuable time.",
    "Using this app to find a plumber was a frustrating experience. It was slow to load available plumbers, and sometimes it would show plumbers as available when they were fully booked. After finally scheduling a service, the app crashed, and my booking was lost. I had to call the plumbing company directly to schedule an appointment.",
    "I attempted to use this app to pay my utility bills, but it was a disaster. It was slow to load available billers, and sometimes it would log me out unexpectedly. After finally managing to add a biller and make a payment, the app crashed, and the payment was not processed. I had to use another method to pay my bills."
]

outputs5 = [
    [
        {"slow to load available appointment slots": ["schedule a home repair"]},
        {"app crashed during confirmation": ["schedule a home repair"]},
        {"booking lost after app restart": ["schedule a home repair"]},
        {"customer support unresponsive": ["schedule a home repair"]}
    ],
    [
        {"sluggish when browsing cake designs": ["order a birthday cake"]},
        {"app froze during checkout": ["order a birthday cake"]},
        {"payment not processed after app crash": ["order a birthday cake"]},
        {"no response from customer service": ["order a birthday cake"]}
    ],
    [
        {"slow to load available tutors": ["find a tutor"]},
        {"tutors shown as available when fully booked": ["find a tutor"]},
        {"booking lost after app crash": ["find a tutor"]},
        {"had to schedule session directly with tutoring center": ["find a tutor"]}
    ],
    [
        {"app crashed when inputting doses": ["track medication"]},
        {"entries deleted without warning": ["track medication"]},
        {"app froze when setting reminders": ["track medication"]},
        {"missed doses due to app's unreliability": ["track medication"]}
    ],
    [
        {"slow to load available walkers": ["find a dog walker"]},
        {"walkers shown as available when they were not": ["find a dog walker"]},
        {"booking lost after app crash": ["find a dog walker"]},
        {"had to find walker through other means": ["find a dog walker"]}
    ],
    [
        {"slow to load available restaurants": ["order meal delivery"]},
        {"places shown as open when they were closed": ["order meal delivery"]},
        {"app crashed during checkout": ["order meal delivery"]},
        {"order lost after app crash": ["order meal delivery"]},
        {"customer support unable to assist": ["order meal delivery"]}
    ],
    [
        {"slow to load available vehicles": ["book a rental car"]},
        {"cars shown as available when they were not": ["book a rental car"]},
        {"booking lost after app crash": ["book a rental car"]},
        {"had to secure reservation directly with rental company": ["book a rental car"]}
    ],
    [
        {"slow to load available items": ["order groceries"]},
        {"products shown as available when out of stock": ["order groceries"]},
        {"app crashed after completing order": ["order groceries"]},
        {"cart emptied after app crash": ["order groceries"]}
    ],
    [
        {"slow to load available plumbers": ["find a plumber"]},
        {"plumbers shown as available when fully booked": ["find a plumber"]},
        {"booking lost after app crash": ["find a plumber"]},
        {"had to schedule appointment directly with plumbing company": ["find a plumber"]}
    ],
    [
        {"slow to load available billers": ["pay utility bills"]},
        {"app logged out unexpectedly": ["pay utility bills"]},
        {"payment not processed after app crash": ["pay utility bills"]},
        {"had to use another method to pay bills": ["pay utility bills"]}
    ]
]

# %%
scenario2_1 = pd.DataFrame({
    "Reviews": reviews1 + reviews2 + reviews3 + reviews4 + reviews5,
    "Outputs": outputs1 + outputs2 + outputs3 + outputs4 + outputs5
})

scenario2_1.head()
# Out:
#                                              Reviews  \
# 0  This app is infuriating. I tried to transfer m...
# 1  Terrible experience trying to pay my utility b...
# 2  I tried booking a flight and hotel package, an...
# 3  Trying to book a rental car was a nightmare. T...
# 4  I tried to log my workout, and it was a frustr...
#
#                                              Outputs
# 0  [{'app crashes': ['transfer money to a friend'...
# 1  [{'app freezes': ['enter payment details for u...
# 2  [{'app times out': ['search for flight and hot...
# 3  [{'app is slow': ['select rental car']}, {'car...
# 4  [{'app takes forever to load': ['log workout']...

# %%
scenario2_1.to_csv("scenario2_1.csv", index=False)
