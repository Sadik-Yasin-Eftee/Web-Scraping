# %%
import pandas as pd

# %%
reviews_scenario_1_1 = [
    "I try to upload a photo before the app crashes.",
    "I log in until the app freezes.",
    "I open the settings menu then the app stops responding.",
    "I click on a notification before the app shuts down.",
    "I start a video call then the app lags.",
    "I send a message before the app crashes.",
    "I switch to another tab until the app becomes unresponsive.",
    "I attempt to open a file before the app crashes.",
    "I try to access my profile until the app freezes.",
    "I navigate to the chat section then the app stops responding.",
    "I tap on a notification before the app shuts down.",
    "I start a call then the app lags.",
    "I write a comment before the app crashes.",
    "I switch to a different view until the app becomes unresponsive.",
    "I try to upload a document before the app crashes.",
    "I login until the app freezes."
]

outputs_scenario_1_1 = [
    {"the app crashes": ["try to upload a photo"]},
    {"the app freezes": ["log in"]},
    {"the app stops responding": ["open the settings menu"]},
    {"the app shuts down": ["click on a notification"]},
    {"the app lags": ["start a video call"]},
    {"the app crashes": ["send a message"]},
    {"the app becomes unresponsive": ["switch to another tab"]},
    {"the app crashes": ["attempt to open a file"]},
    {"the app freezes": ["try to access my profile"]},
    {"the app stops responding": ["navigate to the chat section"]},
    {"the app shuts down": ["tap on a notification"]},
    {"the app lags": ["start a call"]},
    {"the app crashes": ["write a comment"]},
    {"the app becomes unresponsive": ["switch to a different view"]},
    {"the app crashes": ["try to upload a document"]},
    {"the app freezes": ["login"]}
]

# %%
reviews_scenario_1_2 = [
    "Every time I try to log in, it says my session expired and kicks me out.",
    "The app keeps updating constantly, even though I've already updated it.",
    "I can't log into my Facebook account no matter how many times I try.",
    "Facebook's algorithm buries everything I try to share on my wall, making it impossible for anyone to see.",
    "The app logs me out randomly and makes me go through two-factor authentication every time I try to log back in.",
    "Suddenly, the app won't allow me to log in or show anything on my page.",
    "My Facebook completely crashed, and now I can't log in at all. It keeps saying my session expired, and I have no access to my account.",
    "After the latest update, the app won't let me log in or create a new account.",
    "My account got hacked, and now I can't get any help from customer support.",
    "The auto-refresh on the news feed makes it impossible to read articles or comments properly.",
    "I can't block all reels, and the ones I can block keep coming back. ",
    "The app causes unexpected logouts and doesn't let me log back in.",
    "Clicking on a link reloads the whole news feed instead of returning to the post I was reading. It's like the app is playing tricks on me.",
    "The app keeps telling me my session expired, even though I just logged in. It's like it's stuck in a never-ending cycle of logouts.",
    "It won't log me in and keeps saying my session expired. When I try to log in, I just get a blank white page.",
    "The app repeatedly tells me to try again when I try to log in, even after resetting my password.",
]

outputs_scenario_1_2 = [
    [{"session expired": ["try to log in"]}],
    [{"constant updating": ["update the app"]}],
    [{"can't recover account": ["try to recover account"]}],
    [{"algorithm buries posts": ["try to share on wall"]}],
    [{"random logouts": ["try to log back in"]}],
    [{"app won't show anything": ["try to log in"]}],
    [{"complete crash": ["try to log in"]}],
    [{"can't create new account": ["try to log in"]}],
    [{"hacked account": ["try to contact support"]}],
    [{"auto-refresh on news feed": ["read articles"]}],
    [{"can't block reels": ["try to block reels"]}],
    [{"unexpected logouts": ["try to log back in"]}],
    [{"link reloads news feed": ["click on link"]}],
    [{"constant session expiry": ["try to log in"]}],
    [{"session expired, blank page": ["try to log in"]}],
    [{"repeated login attempts": ["try to log in"]}],
]

# %%
reviews_scenario_1_3 = [
    "App constantly crashing when trying to post a status",
    "Notifications not showing up when scrolling through the feed",
    "Videos freezing randomly when watching videos",
    "Messages not sending when trying to send a message",
    "Photos not uploading properly when uploading a photo",
    "Settings not saving changes when accessing settings",
    "Posts disappearing when writing a post",
    "Comments not appearing when commenting on a post",
    "Profile information not updating when updating profile information",
    "Reactions not registering when reacting to a post",
    "Stories not loading when viewing stories",
    "Likes not showing up when liking a post",
    "Shares not going through when trying to share a post",
    "Events not displaying when accessing events",
    "Groups not accessible when trying to join a group",
    "Pages not loading properly when accessing pages",
    "Search results not relevant when searching"
]

outputs_scenario_1_3 = [
    [{"App constantly crashing": ["When trying to post a status"]}],
    [{"Notifications not showing up": ["When scrolling through the feed"]}],
    [{"Videos freezing randomly": ["When watching videos"]}],
    [{"Messages not sending": ["When trying to send a message"]}],
    [{"Photos not uploading properly": ["When uploading a photo"]}],
    [{"Settings not saving changes": ["When accessing settings"]}],
    [{"Posts disappearing": ["When writing a post"]}],
    [{"Comments not appearing": ["When commenting on a post"]}],
    [{"Profile information not updating": ["When updating profile information"]}],
    [{"Reactions not registering": ["When reacting to a post"]}],
    [{"Stories not loading": ["When viewing stories"]}],
    [{"Likes not showing up": ["When liking a post"]}],
    [{"Shares not going through": ["When trying to share a post"]}],
    [{"Events not displaying": ["When accessing events"]}],
    [{"Groups not accessible": ["When trying to join a group"]}],
    [{"Pages not loading properly": ["When accessing pages"]}],
    [{"Search results not relevant": ["When searching"]}]
]

# %%
scenario1 = pd.DataFrame({
    "Reviews": reviews_scenario_1_1 + reviews_scenario_1_2 + reviews_scenario_1_3, 
    "Outputs": list(outputs_scenario_1_1) + list(outputs_scenario_1_2) + list(outputs_scenario_1_3)
})

scenario1.head()
# Out:
#                                              Reviews  \
# 0    I try to upload a photo before the app crashes.
# 1                    I log in until the app freezes.
# 2  I open the settings menu then the app stops re...
# 3  I click on a notification before the app shuts...
# 4            I start a video call then the app lags.
#
#                                              Outputs
# 0     {'the app crashes': ['try to upload a photo']}
# 1                    {'the app freezes': ['log in']}
# 2  {'the app stops responding': ['open the settin...
# 3  {'the app shuts down': ['click on a notificati...
# 4           {'the app lags': ['start a video call']}

# %%
scenario1.to_csv("scenario1.csv", index=False)
