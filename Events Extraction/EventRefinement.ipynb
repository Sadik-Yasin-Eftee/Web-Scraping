# %%
import pandas as pd

# %%
df = pd.read_csv('../App Reviews/Events Dataset/events - events.csv.csv')
df.head()
# Out:
#                                reviewId  \
# 0  83db9a4a-c0c0-4801-a8ff-440b59596bf8
# 1  77174a84-86bb-4d1c-9301-a9cd680fc39a
# 2  eeb30392-007d-40c5-8f50-81383f5371d0
# 3  da10c272-945b-4038-9c2f-cb4ee8c42e63
# 4  6ef27210-bee9-4bfc-b2f1-b242ea5d6548
#
#                                              content  \
# 0  Keeps logging me out of account saying session...
# 1  Facebook marketplace has a bug or a terrible f...
# 2  I don't know what has happened lately it will ...
# 3  Can't login at all can't recover my account at...
# 4  When I try to share things that I like on my w...
#
#                                               events  \
# 0  ['saying session expired and', 'I try to log i...
# 1  ['Facebook marketplace has a bug or a terrible...
# 2  ['all cuz it starts to log in', 'then it decid...
# 3  ["Can't login at all can't recover my account ...
# 4  ['When I try to share things that I like on my...
#
# ...

# %%
df = df[['content','events refined']]
df.head()
# Out:
#                                              content  \
# 0  Keeps logging me out of account saying session...
# 1  Facebook marketplace has a bug or a terrible f...
# 2  I don't know what has happened lately it will ...
# 3  Can't login at all can't recover my account at...
# 4  When I try to share things that I like on my w...
#
#                                       events refined
# 0  [It keeps logging me out, It is saying session...
# 1  [I search and scroll, It will select a random ...
# 2  [I log in with the right password, The app sta...
# 3  [I have tried uninstalling, I tried to get the...
# 4  [I try to share things, it throws it in the ir...

# %%
df = df.dropna()
df.head()
# Out:
#                                              content  \
# 0  Keeps logging me out of account saying session...
# 1  Facebook marketplace has a bug or a terrible f...
# 2  I don't know what has happened lately it will ...
# 3  Can't login at all can't recover my account at...
# 4  When I try to share things that I like on my w...
#
#                                       events refined
# 0  [It keeps logging me out, It is saying session...
# 1  [I search and scroll, It will select a random ...
# 2  [I log in with the right password, The app sta...
# 3  [I have tried uninstalling, I tried to get the...
# 4  [I try to share things, it throws it in the ir...

# %%
df.to_csv('../Training Dataset/FewShotForEvents.csv', index=False)
